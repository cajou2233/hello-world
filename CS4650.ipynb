# %% [markdown]
# <a href="https://colab.research.google.com/github/cajou2233/hello-world/blob/master/CS4650.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy
# !pip install newsapi-python
# !pip install Pandas

# !python -m spacy download en_core_web_lg

# %%
import spacy
import newsapi
import pandas as pd

nlp_eng = spacy.load('en_core_web_sm')
newsapi = newsapi.NewsApiClient (api_key='351bb36c88fd4d0ea61a99bacba42e49')

print(nlp_eng)
print(newsapi)
# Out:
# <spacy.lang.en.English object at 0x7f4cd353ba10>
# <newsapi.newsapi_client.NewsApiClient object at 0x7f4cfb832410>

# %%
articles = newsapi.get_everything(q='coronavirus', language='en', from_param='2021-02-21', to='2021-03-20', sort_by='relevancy')
article=articles["articles"]

# %%
dados=[]
for x in article:
  dados.append({'title':x["title"],'data':x['publishedAt'],'desc':x['description'],'content':x['content']})
df = pd.DataFrame(dados)
df.head()
# Out:
#                                          title  ...                                            content
# 0    Coronavirus Briefing: What Happened Today  ...  But medical ethicists say the list is misleadi...
# 1    Coronavirus Briefing: What Happened Today  ...  Similar laborious efforts may have to be scale...
# 2    Coronavirus Briefing: What Happened Today  ...  What do you think the next few months look lik...
# 3  Your N.B.A. Coronavirus Questions, Answered  ...  Why havent I seen Wayne Knight in the ads for ...
# 4    Coronavirus Briefing: What Happened Today  ...  How is the Green Passport system working, for ...
#
# [5 rows x 4 columns]

# %%
pos_tag=["VERB","NOUN","PRON"]
def compor(e):return e['count']

for a in article:
  keyword=[]
  common={}
  doc=nlp_eng(str(a["title"]) + str(a["content"]) + str(a["description"]))
  for token in doc:
    if (token.text in nlp_eng.Defaults.stop_words):
      continue
    if (token.pos_ in pos_tag):
      keyword.append(token.text)
  for i in keyword:
   if i in common:
     common[i] += 1
   else:
    common[i] = 1
  
  col = []
  for x,y in common.items():
    col.append({"text":x,"count":y})
  col.sort(reverse=True,key=compor)
  
  a["top_words"] = ""
  for x in range(5):
    a["top_words"] += col[x]["text"] + ", "

# %%
result=[]
for x in article:
  result.append({'title':x["title"],'data':x['publishedAt'],'desc':x['description'],'content':x['content'],'top_5':x['top_words']})
df = pd.DataFrame(result)
df
# Out:
#                                                 title  ...                                              top_5
# 0           Coronavirus Briefing: What Happened Today  ...      list, conditions, What, Happened, ethicists,
# 1           Coronavirus Briefing: What Happened Today  ...         What, Happened, efforts, scaled, country,
# 2           Coronavirus Briefing: What Happened Today  ...             going, What, think, months, Happened,
# 3         Your N.B.A. Coronavirus Questions, Answered  ...                           I, seen, ads, m, sorry,
# 4           Coronavirus Briefing: What Happened Today  ...         What, Happened, system, working, example,
# 5           Coronavirus Briefing: What Happened Today  ...        vaccine, What, Happened, sharing, program,
# 6           Coronavirus Briefing: What Happened Today  ...        pandemic, readers, What, Happened, TodayA,
# 7           Coronavirus Briefing: What Happened Today  ...   What, Happened, institutions, struggling, year,
# 8           Coronavirus Briefing: What Happened Today  ...            health, What, Happened, centers, said,
# 9           Coronavirus Briefing: What Happened Today  ...           What, Happened, summer, areas, country,
# 10    Coronavirus, Texas, Mars: Your Weekend Briefing  ...        Weekend, ally, head, security, contractor,
# 11    I.O.C. Will Buy Coronavirus Vaccines From China  ...              Will, Buy, amounts, relations, coup,
# 12  US coronavirus vaccine rollout becomes 'less m...  ...           set, goal, getting, people, vaccinated,
# 13  Assessing Claims in the Coronavirus Stimulus D...  ...   receiving, funding, Assessing, Claims, DebateA,
# 14             Coronavirus Testing Slumps in the U.S.  ...           a.m., experts, cited, factors, percent,
# 15  Keeping the Australian Open Safe from Coronavirus  ...            Keeping, thing, happened, end, plenty,
# 16  Coronavirus: Paraguay president asks ministers...  ...  government, president, ministers, protests, as...
# 17  Virginia Pulls Out of A.C.C. Tournament Becaus...  ...   team, tournament, basketball, champion, pulled,
# 18  UConn Coach Geno Auriemma Tests Positive for t...  ...    basketball, university, womens, coach, tested,
# 19    Experts warn of coronavirus superspreader spike  ...    superspreader, Experts, warn, says, officials,
#
# [20 rows x 5 columns]
